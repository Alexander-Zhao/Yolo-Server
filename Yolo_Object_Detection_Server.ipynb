# %% [markdown]
# <a href="https://colab.research.google.com/github/Chicken-With-Blue-Slippers/Yolo-Server/blob/main/Yolo_Object_Detection_Server.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Download GitHub repository, set it as root directory, and install dependencies

# %%
import os
os.chdir("/content")
#!git clone https://github.com/kmeng01/yolo-server
# !git clone https://github.com/Chicken-With-Blue-Slippers/Yolo-Server
#os.chdir("/content/yolo-server")
os.chdir("/content/Yolo-Server")
# Clone Yolo-Server codes
# !pip install -q modal
# Out:
# fatal: destination path 'Yolo-Server' already exists and is not an empty directory.

# %% [markdown]
# Authenticate [Modal](https://modal.com) account. Visit https://modal.com/settings/tokens to create a token/secret combination.

# %%
# Apply a token-id from Modal server first
# !modal token set --token-id <token-id> --token-secret <token-secret>
# !modal token set --token-id ak-fNMKmefxLj8g81N34fZOr8	 --token-secret as-yGkHcJehurMZd7otviM0cz
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `newline'
# /bin/bash: -c: line 1: `modal token set --token-id <token-id> --token-secret <token-secret>'
# Verifying token against https://api.modal.com
# Token verified successfully
# Token written to /root/.modal.toml

# %% [markdown]
# Serve the application

# %%
# !modal serve main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# requirements: Ultralytics requirements ['gitpython>=3.1.30', 'Pillow>=10.0.1', 'setuptools>=65.5.1'] not found, attempting AutoUpdate...
# requirements: Ultralytics requirements ['gitpython>=3.1.30', 'Pillow>=10.0.1', 'setuptools>=65.5.1'] not found, attempting AutoUpdate...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.32.0 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 52.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 148.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 317.9 MB/s eta 0:00:00
# ...
